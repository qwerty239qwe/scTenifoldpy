# %% [markdown]
# # 2. Run the scTenifoldNet pipeline

# %%
import scTenifold as st
from scTenifold.data import get_test_df

# %%
x_df, y_df = get_test_df(100, 100), get_test_df(100, 100)

# %%
net = st.scTenifoldNet(x_df, y_df, "X", "Y",
                       qc_kws={"min_lib_size": 10})

# %% [markdown]
# ### The quickest way to run scTenifoldNet is to use build() method</br>
# #### This method will use all kws inside the instance to run scTenifold pipeline (qc_kws, nc_kws, td_kws, ma_kws, dr_kws)

# %%
net.build()

# %% [markdown]
# ### Run step separately

# %%
net.run_step("qc")
# Out:
# Removed 0 cells with lib size < 10
# Removed 0 outlier cells from original data
# Found mitochondrial genes: ['MT-1', 'MT-10', 'MT-2', 'MT-3', 'MT-4', 'MT-5', 'MT-6', 'MT-7', 'MT-8', 'MT-9']
# Removed 54 samples from original data (mt genes ratio > 0.1)
# Removed 0 genes expressed in less than 0.05 of data
# Removed 0 genes with expression values: average < 0 or sum < 0
# finish QC: X
# Removed 0 cells with lib size < 10
# Removed 2 outlier cells from original data
# Found mitochondrial genes: ['MT-1', 'MT-10', 'MT-2', 'MT-3', 'MT-4', 'MT-5', 'MT-6', 'MT-7', 'MT-8', 'MT-9']
# Removed 47 samples from original data (mt genes ratio > 0.1)
# Removed 0 genes expressed in less than 0.05 of data
# Removed 0 genes with expression values: average < 0 or sum < 0
# finish QC: Y
# process qc finished in 0.3645961000000284 secs.

# %%
# inspect the results
net.QC_dict["X"]
# Out:
#              Cell-3        Cell-4        Cell-9  Cell-10  Cell-13  Cell-15  \
# gene
# MT-1       0.000000      0.000000      0.000000  20000.0      0.0      0.0
# MT-10      0.000000      0.000000      0.000000  20000.0      0.0      0.0
# MT-2   52631.578947      0.000000      0.000000      0.0      0.0  25000.0
# MT-3       0.000000  27777.777778      0.000000      0.0      0.0      0.0
# MT-4       0.000000      0.000000      0.000000      0.0      0.0      0.0
# ...             ...           ...           ...      ...      ...      ...
# NG-87  26315.789474      0.000000  33333.333333  20000.0      0.0      0.0
# NG-88  26315.789474  27777.777778      0.000000  40000.0      0.0  50000.0
# NG-89      0.000000  27777.777778  33333.333333  20000.0      0.0  25000.0
# NG-9       0.000000  27777.777778      0.000000  20000.0      0.0  25000.0
# NG-90      0.000000      0.000000      0.000000  20000.0      0.0      0.0
#
#             Cell-16       Cell-17       Cell-19       Cell-21  ...  \
# gene                                                           ...
# MT-1   24390.243902      0.000000  27777.777778  23809.523810  ...
# MT-10      0.000000  39215.686275      0.000000      0.000000  ...
# MT-2   24390.243902      0.000000  27777.777778      0.000000  ...
# MT-3       0.000000      0.000000      0.000000  47619.047619  ...
# MT-4       0.000000      0.000000      0.000000      0.000000  ...
# ...             ...           ...           ...           ...  ...
# NG-87      0.000000      0.000000      0.000000  47619.047619  ...
# NG-88      0.000000  19607.843137  27777.777778  23809.523810  ...
# NG-89  24390.243902      0.000000  27777.777778      0.000000  ...
# NG-9   24390.243902      0.000000      0.000000  23809.523810  ...
# NG-90      0.000000      0.000000      0.000000      0.000000  ...
#
#             Cell-77       Cell-78       Cell-80       Cell-84       Cell-85  \
# gene
# MT-1       0.000000      0.000000      0.000000      0.000000      0.000000
# MT-10      0.000000      0.000000  26315.789474      0.000000      0.000000
# MT-2       0.000000      0.000000      0.000000      0.000000      0.000000
# MT-3   27777.777778      0.000000  26315.789474  26315.789474  25641.025641
# MT-4   27777.777778  20833.333333      0.000000  26315.789474      0.000000
# ...             ...           ...           ...           ...           ...
# NG-87      0.000000  20833.333333  26315.789474      0.000000      0.000000
# NG-88      0.000000      0.000000  26315.789474      0.000000  51282.051282
# NG-89  27777.777778  20833.333333      0.000000      0.000000      0.000000
# NG-9   27777.777778      0.000000  52631.578947      0.000000      0.000000
# NG-90      0.000000      0.000000      0.000000  52631.578947  25641.025641
#
#             Cell-86       Cell-91       Cell-97  Cell-99      Cell-100
# gene
# MT-1       0.000000      0.000000      0.000000      0.0  30303.030303
# MT-10      0.000000  23255.813953      0.000000      0.0  30303.030303
# MT-2   30303.030303      0.000000      0.000000      0.0      0.000000
# MT-3       0.000000      0.000000      0.000000      0.0      0.000000
# MT-4       0.000000  23255.813953      0.000000      0.0      0.000000
# ...             ...           ...           ...      ...           ...
# NG-87      0.000000  23255.813953      0.000000      0.0      0.000000
# NG-88  30303.030303      0.000000  23255.813953  25000.0      0.000000
# NG-89      0.000000      0.000000      0.000000      0.0  30303.030303
# NG-9   30303.030303  69767.441860  23255.813953      0.0  30303.030303
# NG-90      0.000000  23255.813953      0.000000  50000.0      0.000000
#
# [100 rows x 46 columns]

# %%
net.run_step("nc", n_cpus=1) # if no n_cpus specified, use all cores to do parallel computing
# Out:
# make_networks  processing time:  10.27852489999998
# make_networks  processing time:  10.232678599999986
# process nc finished in 20.51331379999999 secs.

# %%
net.network_dict["X"]
# Out:
# [<100x100 sparse matrix of type '<class 'numpy.float64'>'
#  	with 500 stored elements in COOrdinate format>,
#  <100x100 sparse matrix of type '<class 'numpy.float64'>'
#  	with 500 stored elements in COOrdinate format>,
#  <100x100 sparse matrix of type '<class 'numpy.float64'>'
#  	with 500 stored elements in COOrdinate format>,
#  <100x100 sparse matrix of type '<class 'numpy.float64'>'
#  	with 500 stored elements in COOrdinate format>,
#  <100x100 sparse matrix of type '<class 'numpy.float64'>'
#  	with 500 stored elements in COOrdinate format>,
#  <100x100 sparse matrix of type '<class 'numpy.float64'>'
#  	with 500 stored elements in COOrdinate format>,
#  <100x100 sparse matrix of type '<class 'numpy.float64'>'
#  	with 500 stored elements in COOrdinate format>,
#  <100x100 sparse matrix of type '<class 'numpy.float64'>'
#  	with 500 stored elements in COOrdinate format>,
#  <100x100 sparse matrix of type '<class 'numpy.float64'>'
#  	with 500 stored elements in COOrdinate format>,
#  <100x100 sparse matrix of type '<class 'numpy.float64'>'
#  	with 500 stored elements in COOrdinate format>]

# %%
net.run_step("td")
# Out:
# Using tensorly
# (100, 100, 10)
# tensor_decomp  processing time:  0.2734854999999925
# Using tensorly
# (100, 100, 10)
# tensor_decomp  processing time:  0.19949509999997872
# process td finished in 0.47945240000001377 secs.

# %%
net.tensor_dict["X"]
# Out:
#        NG-64  NG-6  NG-50  NG-4  NG-12  NG-15  NG-16  NG-58  NG-60  NG-17  \
# NG-64    0.0 -0.00  -0.00   0.0   0.00   -0.0   0.00  -0.00   0.00   0.00
# NG-6    -0.0  0.50  -0.00  -0.0  -0.10    0.0  -0.60   0.20   0.00   0.20
# NG-50   -0.0 -0.00   0.00  -0.0   0.00    0.0   0.05  -0.00   0.00  -0.00
# NG-4     0.0 -0.00  -0.00   0.0  -0.00   -0.0   0.00  -0.00   0.00   0.00
# NG-12    0.0 -0.10   0.00  -0.0   0.10    0.0   0.10  -0.00   0.00  -0.15
# ...      ...   ...    ...   ...    ...    ...    ...    ...    ...    ...
# NG-22    0.0 -0.65   0.05   0.0   0.15    0.0   0.90  -0.35   0.05  -0.35
# NG-9     0.0 -0.00  -0.00   0.0  -0.00   -0.0   0.00  -0.00   0.00   0.00
# NG-23    0.0 -0.05   0.00  -0.0   0.00    0.0   0.10  -0.05   0.00  -0.05
# NG-5    -0.0  0.45  -0.00  -0.0  -0.15    0.0  -0.45   0.20   0.00   0.25
# NG-32    0.0  0.00   0.00   0.0   0.00    0.0   0.00   0.00   0.00   0.00
#
#        ...  NG-30  MT-7  NG-79  NG-53  NG-21  NG-22  NG-9  NG-23  NG-5  NG-32
# NG-64  ...  -0.00  0.00   0.00   -0.0    0.0   0.00   0.0   0.00 -0.00    0.0
# NG-6   ...  -0.10  0.00   0.10    0.0   -0.0  -0.65  -0.0  -0.05  0.45    0.0
# NG-50  ...  -0.00 -0.00   0.00    0.0   -0.0   0.05  -0.0   0.00 -0.00    0.0
# NG-4   ...   0.00  0.00  -0.00   -0.0    0.0   0.00   0.0  -0.00 -0.00    0.0
# NG-12  ...   0.10  0.00  -0.10   -0.0    0.0   0.15  -0.0   0.00 -0.15    0.0
# ...    ...    ...   ...    ...    ...    ...    ...   ...    ...   ...    ...
# NG-22  ...  -0.10 -0.05   0.10   -0.0    0.0   1.00   0.0   0.20 -0.45    0.0
# NG-9   ...  -0.00  0.00   0.00   -0.0    0.0   0.00   0.0   0.00 -0.00    0.0
# NG-23  ...  -0.30 -0.00   0.30   -0.0    0.0   0.20   0.0   0.30  0.10    0.0
# NG-5   ...  -0.35  0.00   0.35    0.0   -0.0  -0.45  -0.0   0.10  0.60    0.0
# NG-32  ...   0.00  0.00   0.00    0.0    0.0   0.00   0.0   0.00  0.00    0.0
#
# [100 rows x 100 columns]

# %%
net.run_step("ma")
# Out:
# manifold_alignment  processing time:  0.16083390000000009
# process ma finished in 0.16095510000002378 secs.

# %%
net.manifold
# Out:
#                      NLMA_1              NLMA_2              NLMA_3  \
# X_NG-64 -0.004793+0.000000j  0.011921+0.000000j  0.008759+0.000000j
# X_NG-6   0.051211+0.000000j  0.067053+0.000000j  0.003497+0.000000j
# X_NG-50  0.047110+0.000000j  0.002341+0.000000j  0.076045+0.000000j
# X_NG-4   0.001425+0.000000j  0.041213+0.000000j  0.010475+0.000000j
# X_NG-12 -0.006091+0.000000j -0.065287+0.000000j -0.055578+0.000000j
# ...                     ...                 ...                 ...
# Y_NG-22 -0.004593+0.000000j  0.031088+0.000000j  0.019867+0.000000j
# Y_NG-9   0.000874+0.000000j -0.059116+0.000000j -0.010239+0.000000j
# Y_NG-23 -0.052597+0.000000j  0.141476+0.000000j  0.132878+0.000000j
# Y_NG-5  -0.020735+0.000000j -0.034524+0.000000j -0.030183+0.000000j
# Y_NG-32 -0.040097+0.000000j  0.092214+0.000000j -0.108480+0.000000j
#
#                      NLMA_4              NLMA_5              NLMA_6  \
# X_NG-64  0.004662+0.000000j  0.023253+0.000000j -0.022233+0.000000j
# X_NG-6   0.015538+0.000000j  0.019158+0.000000j  0.006468+0.000000j
# X_NG-50  0.019364+0.000000j  0.022135+0.000000j -0.048259+0.000000j
# X_NG-4  -0.054829+0.000000j  0.020559+0.000000j -0.155373+0.000000j
# X_NG-12  0.027281+0.000000j  0.023779+0.000000j  0.005236+0.000000j
# ...                     ...                 ...                 ...
# Y_NG-22 -0.008674+0.000000j -0.019975+0.000000j -0.044163+0.000000j
# Y_NG-9   0.020600+0.000000j  0.013303+0.000000j  0.027719+0.000000j
# Y_NG-23  0.000435+0.000000j  0.107108+0.000000j -0.147903+0.000000j
# Y_NG-5   0.006206+0.000000j  0.072601+0.000000j -0.032187+0.000000j
# Y_NG-32  0.029601+0.000000j -0.000569+0.000000j  0.071849+0.000000j
#
#                      NLMA_7              NLMA_8              NLMA_9  \
# X_NG-64 -0.014833+0.000000j  0.010190+0.000000j -0.019788+0.000000j
# X_NG-6  -0.040182+0.000000j  0.011301+0.000000j  0.034917+0.000000j
# X_NG-50  0.116425+0.000000j -0.001764+0.000000j -0.017967+0.000000j
# X_NG-4  -0.056135+0.000000j -0.121298+0.000000j  0.009866+0.000000j
# X_NG-12 -0.016125+0.000000j  0.043306+0.000000j -0.035671+0.000000j
# ...                     ...                 ...                 ...
# Y_NG-22 -0.002299+0.000000j  0.057494+0.000000j -0.021659+0.000000j
# Y_NG-9  -0.019123+0.000000j  0.014988+0.000000j -0.024534+0.000000j
# Y_NG-23 -0.000191+0.000000j  0.030780+0.000000j -0.044629+0.000000j
# Y_NG-5  -0.022373+0.000000j  0.039236+0.000000j -0.036286+0.000000j
# Y_NG-32 -0.088941+0.000000j -0.026086+0.000000j -0.012750+0.000000j
#
#                     NLMA_10  ...             NLMA_21             NLMA_22  \
# X_NG-64  0.029424+0.000000j  ... -0.078091+0.000000j  0.019393+0.000000j
# X_NG-6   0.044967+0.000000j  ...  0.015140+0.000000j -0.008660+0.000000j
# X_NG-50  0.024994+0.000000j  ...  0.039317+0.000000j  0.110950+0.000000j
# X_NG-4  -0.419491+0.000000j  ...  0.044432+0.000000j  0.035311+0.000000j
# X_NG-12  0.029351+0.000000j  ...  0.021251+0.000000j -0.021533+0.000000j
# ...                     ...  ...                 ...                 ...
# Y_NG-22 -0.002221+0.000000j  ... -0.032764+0.000000j -0.047987+0.000000j
# Y_NG-9   0.030277+0.000000j  ...  0.035181+0.000000j -0.006352+0.000000j
# Y_NG-23  0.081941+0.000000j  ... -0.098499+0.000000j  0.113186+0.000000j
# Y_NG-5   0.005677+0.000000j  ... -0.042392+0.000000j -0.014943+0.000000j
# Y_NG-32  0.034675+0.000000j  ...  0.004873+0.000000j -0.018576+0.000000j
#
#                     NLMA_23             NLMA_24             NLMA_25  \
# X_NG-64 -0.123674+0.000000j  0.023010+0.000000j  0.524141+0.000000j
# X_NG-6  -0.014198+0.000000j  0.001215+0.000000j -0.007581+0.000000j
# X_NG-50 -0.055688+0.000000j  0.201690+0.000000j  0.040230+0.000000j
# X_NG-4   0.008267+0.000000j -0.010755+0.000000j -0.004122+0.000000j
# X_NG-12  0.011521+0.000000j  0.027851+0.000000j -0.001254+0.000000j
# ...                     ...                 ...                 ...
# Y_NG-22  0.046395+0.000000j -0.018640+0.000000j  0.003974+0.000000j
# Y_NG-9  -0.044172+0.000000j -0.049176+0.000000j -0.065117+0.000000j
# Y_NG-23 -0.056271+0.000000j -0.069089+0.000000j -0.023050+0.000000j
# Y_NG-5   0.014734+0.000000j -0.000670+0.000000j -0.009681+0.000000j
# Y_NG-32 -0.019403+0.000000j -0.015474+0.000000j -0.012627+0.000000j
#
#                     NLMA_26             NLMA_27             NLMA_28  \
# X_NG-64 -0.389833+0.000000j  0.083951+0.000000j  0.084645+0.000000j
# X_NG-6  -0.024510+0.000000j  0.040684+0.000000j -0.001621+0.000000j
# X_NG-50  0.268045+0.000000j  0.315587+0.000000j  0.375913+0.000000j
# X_NG-4  -0.004822+0.000000j  0.002206+0.000000j -0.014455+0.000000j
# X_NG-12 -0.048201+0.000000j  0.044894+0.000000j -0.040386+0.000000j
# ...                     ...                 ...                 ...
# Y_NG-22 -0.001127+0.000000j  0.001750+0.000000j -0.037872+0.000000j
# Y_NG-9   0.004491+0.000000j -0.232305+0.000000j  0.091620+0.000000j
# Y_NG-23  0.094897+0.000000j -0.171067+0.000000j -0.043999+0.000000j
# Y_NG-5   0.010353+0.000000j -0.014835+0.000000j -0.019586+0.000000j
# Y_NG-32  0.002343+0.000000j  0.005357+0.000000j -0.005161+0.000000j
#
#                     NLMA_29             NLMA_30
# X_NG-64  0.036430+0.000000j -0.024494+0.000000j
# X_NG-6   0.023991+0.000000j -0.001234+0.000000j
# X_NG-50  0.025943+0.000000j -0.045076+0.000000j
# X_NG-4  -0.009544+0.000000j  0.012252+0.000000j
# X_NG-12  0.065592+0.000000j  0.095657+0.000000j
# ...                     ...                 ...
# Y_NG-22  0.032576+0.000000j  0.030560+0.000000j
# Y_NG-9   0.532191+0.000000j -0.220697+0.000000j
# Y_NG-23 -0.134949+0.000000j -0.067248+0.000000j
# Y_NG-5   0.017395+0.000000j  0.057746+0.000000j
# Y_NG-32  0.012805+0.000000j -0.013813+0.000000j
#
# [200 rows x 30 columns]

# %%
net.run_step("dr")
# Out:
# d_regulation  processing time:  0.039106199999991986
# process dr finished in 0.03924669999997832 secs.

# %%
net.d_regulation
# Out:
#      Gene      Distance  boxcox-transformed distance         Z            FC  \
# 82  NG-10  3.664084e-03                    -2.934601  2.089559  8.780721e+00
# 7   NG-58  3.297064e-03                    -2.958454  1.937253  7.109747e+00
# 6   NG-16  3.292691e-03                    -2.958750  1.935364  7.090896e+00
# 46  NG-59  3.250139e-03                    -2.961643  1.916892  6.908810e+00
# 45  NG-36  3.026132e-03                    -2.977351  1.816589  5.989286e+00
# ..    ...           ...                          ...       ...           ...
# 29  NG-74  7.878730e-05                    -3.488758 -1.448865  4.059866e-03
# 89   MT-4  7.108488e-05                    -3.497241 -1.503031  3.304865e-03
# 93  NG-53  6.070130e-05                    -3.509824 -1.583376  2.409879e-03
# 10  NG-76  6.053955e-05                    -3.510032 -1.584705  2.397053e-03
# 79  NG-38  4.741610e-16                    -3.806570 -3.478166  1.470452e-25
#
#      p-value  adjusted p-value
# 82  0.003044          0.304431
# 7   0.007667          0.383330
# 6   0.007748          0.258255
# 46  0.008577          0.214430
# 45  0.014393          0.287861
# ..       ...               ...
# 29  0.949196          0.988745
# 89  0.954156          0.983666
# 93  0.960847          0.980456
# 10  0.960951          0.970658
# 79  1.000000          1.000000
#
# [100 rows x 7 columns]

# %% [markdown]
# ### Save outputed objects: pcNets, tensor decompositions, manifold alignments, regulation dataframe

# %%
net.save("./path")
# Out:
# X.csv has been saved successfully.
# Y.csv has been saved successfully.
